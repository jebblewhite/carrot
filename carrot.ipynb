# %% [markdown]
# Here is my data science playground. I intend to perform basic data manipulation and visualisation of world carrot production data. This directory will be hosted on my public github.
# 🥕

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("carrot_data.csv")

df
# Out:
#       Domain Code Domain  Area Code      Area  Element Code         Element  \
# 0              QC  Crops          3   Albania          5312  Area harvested
# 1              QC  Crops          3   Albania          5312  Area harvested
# 2              QC  Crops          3   Albania          5312  Area harvested
# 3              QC  Crops          3   Albania          5312  Area harvested
# 4              QC  Crops          3   Albania          5312  Area harvested
# ...           ...    ...        ...       ...           ...             ...
# 19497          QC  Crops        181  Zimbabwe          5510      Production
# 19498          QC  Crops        181  Zimbabwe          5510      Production
# 19499          QC  Crops        181  Zimbabwe          5510      Production
# 19500          QC  Crops        181  Zimbabwe          5510      Production
# 19501          QC  Crops        181  Zimbabwe          5510      Production
#
# ...

# %% [markdown]
# ok

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19502 entries, 0 to 19501
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       19502 non-null  object
#  1   Domain            19502 non-null  object
#  2   Area Code         19502 non-null  int64
#  3   Area              19502 non-null  object
#  4   Element Code      19502 non-null  int64
#  5   Element           19502 non-null  object
#  6   Item Code         19502 non-null  int64
#  7   Item              19502 non-null  object
#  8   Year Code         19502 non-null  int64
#  9   Year              19502 non-null  int64
#  10  Unit              19502 non-null  object
#  11  Value             17534 non-null  float64
#  12  Flag              11448 non-null  object
#  13  Flag Description  19502 non-null  object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 2.1+ MB

# %%
df = df.loc[df['Value'] > 0]

# %%
df_prod = df.loc[df['Element'] == 'Production']

# %%
productionval = df_prod["Value"]
sns.displot(productionval)
plt.show()

# %%
productionval.describe()
# Out:
# count    5.913000e+03
# mean     2.354374e+05
# std      1.184523e+06
# min      1.000000e+00
# 25%      3.420000e+03
# 50%      3.050000e+04
# 75%      1.344000e+05
# max      2.072024e+07
# Name: Value, dtype: float64

# %%
china_prod_yrs = df_prod.loc[df['Area' ] == 'China']

# %%
china_prod_yrs
# Out:
#      Domain Code Domain  Area Code   Area  Element Code     Element  \
# 3285          QC  Crops        351  China          5510  Production
# 3286          QC  Crops        351  China          5510  Production
# 3287          QC  Crops        351  China          5510  Production
# 3288          QC  Crops        351  China          5510  Production
# 3289          QC  Crops        351  China          5510  Production
# 3290          QC  Crops        351  China          5510  Production
# 3291          QC  Crops        351  China          5510  Production
# 3292          QC  Crops        351  China          5510  Production
# 3293          QC  Crops        351  China          5510  Production
# 3294          QC  Crops        351  China          5510  Production
# 3295          QC  Crops        351  China          5510  Production
# 3296          QC  Crops        351  China          5510  Production
# 3297          QC  Crops        351  China          5510  Production
# ...

# %%
plt.plot(china_prod_yrs['Year'],china_prod_yrs['Value'])
plt.show()

# %%
for country in df_prod['Area']:
    values = df_prod.loc[df_prod['Area'  == country]]
    plt.plot(df_prod['Year'],values)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-b259a30c89ac> in <module>
# ...

# %%
df_prod.groupby(['Area']).mean()
# Out:
#                                     Area Code  Element Code  Item Code  \
# Area
# Albania                                   3.0        5510.0      426.0
# Algeria                                   4.0        5510.0      426.0
# Antigua and Barbuda                       8.0        5510.0      426.0
# Argentina                                 9.0        5510.0      426.0
# Armenia                                   1.0        5510.0      426.0
# ...                                       ...           ...        ...
# Uzbekistan                              235.0        5510.0      426.0
# Venezuela (Bolivarian Republic of)      236.0        5510.0      426.0
# Yemen                                   249.0        5510.0      426.0
# Yugoslav SFR                            248.0        5510.0      426.0
# Zimbabwe                                181.0        5510.0      426.0
#
#                                     Year Code    Year          Value
# Area
# ...

# %%
df_prod['Area'].unique()
# Out:
# array(['Albania', 'Algeria', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belgium-Luxembourg', 'Belize',
#        'Bermuda', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'China', 'China, mainland',
#        'China, Taiwan Province of', 'Colombia', 'Congo', 'Costa Rica',
#        'Croatia', 'Cyprus', 'Czechia', 'Czechoslovakia',
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'Estonia',
#        'Ethiopia', 'Finland', 'France', 'French Polynesia', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guadeloupe', 'Guatemala',
#        'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran (Islamic Republic of)', 'Iraq', 'Ireland', 'Israel', 'Italy',
# ...

# %%
country = 'Albania'
values = df_prod.loc[df_prod['Area']  == country]
values
# Out:
#     Domain Code Domain  Area Code     Area  Element Code     Element  \
# 116          QC  Crops          3  Albania          5510  Production
# 117          QC  Crops          3  Albania          5510  Production
# 118          QC  Crops          3  Albania          5510  Production
# 119          QC  Crops          3  Albania          5510  Production
# 120          QC  Crops          3  Albania          5510  Production
# 121          QC  Crops          3  Albania          5510  Production
# 122          QC  Crops          3  Albania          5510  Production
# 123          QC  Crops          3  Albania          5510  Production
# 124          QC  Crops          3  Albania          5510  Production
# 125          QC  Crops          3  Albania          5510  Production
# 126          QC  Crops          3  Albania          5510  Production
# 127          QC  Crops          3  Albania          5510  Production
# 128          QC  Crops          3  Albania          5510  Production
# ...

# %%
for country in df_prod['Area'].unique():
    values = df_prod.loc[df_prod['Area']  == country]
    plt.plot(values.Year,values.Value,label=country)
    plt.legend()
    plt.show()

# %%
plt.rcParams["figure.figsize"] = (20,20)
for country in df_prod['Area'].unique():
    values = df_prod.loc[df_prod['Area']  == country]
    plt.plot(values.Year,values.Value,label=country)
    plt.legend()
plt.show()

# %%
""" find the top ten countries 
    find max value for each country
    


"""
df_concise1 = df_prod["Area"]
df_concise2 = df_prod["Value"]

df_concise = pd.merge(df_concise1,df_concise2)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-108-c628e2aff63a> in <module>
#       8 df_concise2 = df_prod["Value"]
#       9
# ---> 10 df_concise = pd.merge(df_concise1,df_concise2)
#
# ~/opt/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~/opt/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     643             warnings.warn(msg, UserWarning)
#     644
# --> 645         self._validate_specification()
# ...

# %%
maxvalues = df_concise
